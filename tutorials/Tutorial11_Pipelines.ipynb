# %% [markdown]
# # Pipelines Tutorial
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/deepset-ai/haystack/blob/master/tutorials/Tutorial11_Pipelines.ipynb)
#
# In this tutorial, you will learn how the `Pipeline` class acts as a connector between all the different
# building blocks that are found in FARM. Whether you are using a Reader, Generator, Summarizer
# or Retriever (or 2), the `Pipeline` class will help you build a Directed Acyclic Graph (DAG) that
# determines how to route the output of one component into the input of another.

# %% [markdown]
# ## Setting Up the Environment
#
# Let's start by ensuring we have a GPU running to ensure decent speed in this tutorial.
# In Google colab, you can change to a GPU runtime in the menu:
# - **Runtime -> Change Runtime type -> Hardware accelerator -> GPU**

# %%
# Make sure you have a GPU running
# !nvidia-smi
# Out:
# Wed Nov 10 18:14:05 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1070    Off  | 00000000:01:00.0  On |                  N/A |
# |  0%   59C    P2    42W / 230W |   1948MiB /  8116MiB |      8%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1286      G   /usr/lib/xorg/Xorg                398MiB |
# |    0   N/A  N/A      1564      G   /usr/bin/gnome-shell              109MiB |
# |    0   N/A  N/A      3361      G   ...AAAAAAAAA= --shared-files       27MiB |
# |    0   N/A  N/A      3484      G   /usr/lib/firefox/firefox          288MiB |
# |    0   N/A  N/A      7025      G   ...2gtk-4.0/WebKitWebProcess       14MiB |
# |    0   N/A  N/A     39718      G   ..._11224.log --shared-files       24MiB |
# |    0   N/A  N/A     44532      C   .../envs/haystack/bin/python     1069MiB |
# |    0   N/A  N/A     46987      G   .../debug.log --shared-files        8MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# These lines are to install Haystack through pip

# %%
# Install the latest release of Haystack in your own environment
# !pip install farm-haystack

# Install the latest master of Haystack
# !pip install grpcio-tools==1.34.1
# !pip install --upgrade git+https://github.com/deepset-ai/haystack.git

# Install  pygraphviz
# !apt install libgraphviz-dev
# !pip install pygraphviz

# If you run this notebook on Google Colab, you might need to
# restart the runtime after installing haystack.
# Out:
# Requirement already satisfied: farm-haystack in /home/branden/Code/haystack (1.0.0rc1)
# Requirement already satisfied: setuptools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (49.2.0.post20200714)
# Requirement already satisfied: wheel in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.34.2)
# Requirement already satisfied: torch<1.10,>1.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.6.0)
# Requirement already satisfied: tqdm in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (4.47.0)
# Requirement already satisfied: requests in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (2.24.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.5.0)
# Requirement already satisfied: sklearn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.0)
# Requirement already satisfied: seqeval in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.0.12)
# Requirement already satisfied: mlflow<=1.13.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.0.0)
# Requirement already satisfied: transformers==4.7.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (4.7.0)
# Requirement already satisfied: dill in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.3.3)
# Requirement already satisfied: psutil in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (5.7.0)
# Requirement already satisfied: fastapi in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.61.2)
# Requirement already satisfied: uvicorn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.12.2)
# Requirement already satisfied: gunicorn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (20.0.4)
# Requirement already satisfied: pandas in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.0.5)
# Requirement already satisfied: elasticsearch<=7.10,>=7.7 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (7.9.1)
# Requirement already satisfied: elastic-apm in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (5.9.0)
# Requirement already satisfied: tox in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (3.20.1)
# Requirement already satisfied: coverage in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (5.3)
# Requirement already satisfied: langdetect in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.0.8)
# Requirement already satisfied: pytesseract==0.3.7 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.3.7)
# Requirement already satisfied: pillow==8.3.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (8.3.2)
# Requirement already satisfied: pdf2image==1.14.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.14.0)
# Requirement already satisfied: sentence-transformers>=0.4.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (2.1.0)
# Requirement already satisfied: python-multipart in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.0.5)
# Requirement already satisfied: python-docx in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.8.10)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.4.26)
# Requirement already satisfied: sqlalchemy_utils in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.36.8)
# Requirement already satisfied: faiss-cpu>=1.6.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.6.3)
# Requirement already satisfied: tika in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.24)
# Requirement already satisfied: httptools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.1.1)
# Requirement already satisfied: nltk in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (3.5)
# Requirement already satisfied: more_itertools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (8.4.0)
# Requirement already satisfied: networkx in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (2.4)
# Requirement already satisfied: pymilvus in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.1.1)
# Requirement already satisfied: SPARQLWrapper in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.8.5)
# Requirement already satisfied: mmh3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (3.0.0)
# Requirement already satisfied: weaviate-client==2.5.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (2.5.0)
# Requirement already satisfied: ray==1.5.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (1.5.0)
# Requirement already satisfied: dataclasses-json in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.5.6)
# Requirement already satisfied: quantulum3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.7.9)
# Requirement already satisfied: psycopg2-binary in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (2.8.6)
# Requirement already satisfied: uvloop==0.14 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack) (0.14.0)
# Requirement already satisfied: numpy in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from torch<1.10,>1.5->farm-haystack) (1.18.5)
# Requirement already satisfied: future in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from torch<1.10,>1.5->farm-haystack) (0.18.2)
# Requirement already satisfied: idna<3,>=2.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack) (1.25.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack) (3.0.4)
# Requirement already satisfied: scikit-learn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sklearn->farm-haystack) (0.23.1)
# Requirement already satisfied: Keras>=2.2.4 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from seqeval->farm-haystack) (2.4.3)
# Requirement already satisfied: click>=7.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (7.1.2)
# Requirement already satisfied: docker>=3.6.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (4.3.1)
# Requirement already satisfied: alembic in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (1.4.3)
# Requirement already satisfied: cloudpickle in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (1.5.0)
# Requirement already satisfied: python-dateutil in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (2.8.1)
# Requirement already satisfied: databricks-cli>=0.8.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (0.14.0)
# Requirement already satisfied: sqlparse in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (0.4.1)
# Requirement already satisfied: entrypoints in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (0.3)
# Requirement already satisfied: simplejson in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (3.17.2)
# Requirement already satisfied: gitpython>=2.1.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (3.1.11)
# Requirement already satisfied: six>=1.10.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (1.15.0)
# Requirement already satisfied: pyyaml in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (5.3.1)
# Requirement already satisfied: Flask in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (1.1.2)
# Requirement already satisfied: querystring-parser in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (1.2.4)
# Requirement already satisfied: protobuf>=3.6.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack) (3.13.0)
# Requirement already satisfied: huggingface-hub==0.0.8 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack) (0.0.8)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack) (0.10.3)
# Requirement already satisfied: packaging in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack) (20.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack) (2020.6.8)
# Requirement already satisfied: filelock in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack) (3.0.12)
# Requirement already satisfied: sacremoses in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack) (0.0.43)
# Requirement already satisfied: starlette==0.13.6 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from fastapi->farm-haystack) (0.13.6)
# Requirement already satisfied: pydantic<2.0.0,>=1.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from fastapi->farm-haystack) (1.7.2)
# Requirement already satisfied: h11>=0.8 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from uvicorn->farm-haystack) (0.11.0)
# Requirement already satisfied: pytz>=2017.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pandas->farm-haystack) (2020.1)
# Requirement already satisfied: py>=1.4.17 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack) (1.9.0)
# Requirement already satisfied: toml>=0.9.4 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack) (0.10.1)
# Requirement already satisfied: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack) (20.1.0)
# Requirement already satisfied: pluggy>=0.12.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack) (0.13.1)
# Requirement already satisfied: torchvision in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack) (0.11.1)
# Requirement already satisfied: sentencepiece in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack) (0.1.94)
# Requirement already satisfied: lxml>=2.3.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from python-docx->farm-haystack) (4.5.2)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sqlalchemy>=1.4.2->farm-haystack) (0.4.16)
# Requirement already satisfied: joblib in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from nltk->farm-haystack) (0.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from networkx->farm-haystack) (4.4.2)
# Requirement already satisfied: grpcio-tools<1.38.0,>=1.22.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pymilvus->farm-haystack) (1.35.0)
# Requirement already satisfied: grpcio<1.38.0,>=1.22.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pymilvus->farm-haystack) (1.35.0)
# Requirement already satisfied: ujson>=2.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pymilvus->farm-haystack) (4.0.2)
# Requirement already satisfied: rdflib>=4.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from SPARQLWrapper->farm-haystack) (6.0.2)
# Requirement already satisfied: validators>=0.18.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from weaviate-client==2.5.0->farm-haystack) (0.18.2)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (0.8.0)
# Requirement already satisfied: aiohttp in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (3.7.4.post0)
# Requirement already satisfied: opencensus in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (0.8.0)
# Requirement already satisfied: gpustat in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (0.6.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (1.0.0)
# Requirement already satisfied: redis>=3.5.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (3.5.3)
# Requirement already satisfied: colorama in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (0.4.3)
# Requirement already satisfied: aioredis in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (2.0.0)
# Requirement already satisfied: aiohttp-cors in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (0.7.0)
# Requirement already satisfied: py-spy>=0.2.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (0.3.10)
# Requirement already satisfied: jsonschema in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack) (3.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from dataclasses-json->farm-haystack) (3.14.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from dataclasses-json->farm-haystack) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from dataclasses-json->farm-haystack) (0.7.1)
# Requirement already satisfied: num2words in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from quantulum3->farm-haystack) (0.5.10)
# Requirement already satisfied: inflect in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from quantulum3->farm-haystack) (5.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn->farm-haystack) (2.1.0)
# Requirement already satisfied: h5py in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Keras>=2.2.4->seqeval->farm-haystack) (2.10.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from docker>=3.6.0->mlflow<=1.13.1->farm-haystack) (0.57.0)
# Requirement already satisfied: Mako in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from alembic->mlflow<=1.13.1->farm-haystack) (1.1.3)
# Requirement already satisfied: python-editor>=0.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from alembic->mlflow<=1.13.1->farm-haystack) (1.0.4)
# Requirement already satisfied: tabulate>=0.7.7 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from databricks-cli>=0.8.0->mlflow<=1.13.1->farm-haystack) (0.8.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack) (4.0.5)
# Requirement already satisfied: Werkzeug>=0.15 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack) (0.16.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from packaging->transformers==4.7.0->farm-haystack) (2.4.7)
# Requirement already satisfied: appdirs<2,>=1.4.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack) (0.3.1)
# Requirement already satisfied: isodate in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper->farm-haystack) (0.6.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack) (19.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack) (3.7.4.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack) (1.7.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack) (5.2.0)
# Requirement already satisfied: opencensus-context==0.1.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from opencensus->ray==1.5.0->farm-haystack) (0.1.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0; python_version >= "3.6" in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from opencensus->ray==1.5.0->farm-haystack) (2.1.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gpustat->ray==1.5.0->farm-haystack) (7.352.0)
# Requirement already satisfied: blessings>=1.6 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gpustat->ray==1.5.0->farm-haystack) (1.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from jsonschema->ray==1.5.0->farm-haystack) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->farm-haystack) (0.4.3)
# Requirement already satisfied: docopt>=0.6.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from num2words->quantulum3->farm-haystack) (0.6.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Mako->alembic->mlflow<=1.13.1->farm-haystack) (1.1.1)
# Requirement already satisfied: smmap<4,>=3.0.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack) (3.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack) (1.53.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack) (2.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack) (4.2.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack) (0.4.8)
# Collecting grpcio-tools==1.34.1
#   Downloading grpcio_tools-1.34.1-cp38-cp38-manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<4.0dev,>=3.5.0.post1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from grpcio-tools==1.34.1) (3.13.0)
# Requirement already satisfied: setuptools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from grpcio-tools==1.34.1) (49.2.0.post20200714)
# Requirement already satisfied: grpcio>=1.34.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from grpcio-tools==1.34.1) (1.35.0)
# Requirement already satisfied: six>=1.9 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from protobuf<4.0dev,>=3.5.0.post1->grpcio-tools==1.34.1) (1.15.0)
# Installing collected packages: grpcio-tools
#   Attempting uninstall: grpcio-tools
#     Found existing installation: grpcio-tools 1.35.0
#     Uninstalling grpcio-tools-1.35.0:
#       Successfully uninstalled grpcio-tools-1.35.0
# Successfully installed grpcio-tools-1.34.1
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-7v8hb23x
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-7v8hb23x
# Requirement already satisfied, skipping upgrade: setuptools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (49.2.0.post20200714)
# Requirement already satisfied, skipping upgrade: wheel in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.34.2)
# Requirement already satisfied, skipping upgrade: torch<1.10,>1.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.6.0)
# Requirement already satisfied, skipping upgrade: tqdm in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (4.47.0)
# Requirement already satisfied, skipping upgrade: requests in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.24.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.5.0)
# Requirement already satisfied, skipping upgrade: sklearn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.0)
# Requirement already satisfied, skipping upgrade: seqeval in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.0.12)
# Requirement already satisfied, skipping upgrade: mlflow<=1.13.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.0.0)
# Requirement already satisfied, skipping upgrade: transformers==4.7.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (4.7.0)
# Requirement already satisfied, skipping upgrade: dill in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.3.3)
# Requirement already satisfied, skipping upgrade: psutil in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (5.7.0)
# Requirement already satisfied, skipping upgrade: fastapi in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.61.2)
# Requirement already satisfied, skipping upgrade: uvicorn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.12.2)
# Requirement already satisfied, skipping upgrade: gunicorn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (20.0.4)
# Requirement already satisfied, skipping upgrade: pandas in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.0.5)
# Requirement already satisfied, skipping upgrade: elasticsearch<=7.10,>=7.7 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (7.9.1)
# Requirement already satisfied, skipping upgrade: elastic-apm in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (5.9.0)
# Requirement already satisfied, skipping upgrade: tox in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (3.20.1)
# Requirement already satisfied, skipping upgrade: coverage in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (5.3)
# Requirement already satisfied, skipping upgrade: langdetect in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.0.8)
# Requirement already satisfied, skipping upgrade: pytesseract==0.3.7 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.3.7)
# Requirement already satisfied, skipping upgrade: pillow==8.3.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (8.3.2)
# Requirement already satisfied, skipping upgrade: pdf2image==1.14.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.14.0)
# Requirement already satisfied, skipping upgrade: sentence-transformers>=0.4.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.1.0)
# Requirement already satisfied, skipping upgrade: python-multipart in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.0.5)
# Requirement already satisfied, skipping upgrade: python-docx in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.8.10)
# Requirement already satisfied, skipping upgrade: sqlalchemy>=1.4.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.4.26)
# Requirement already satisfied, skipping upgrade: sqlalchemy_utils in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.36.8)
# Requirement already satisfied, skipping upgrade: faiss-cpu>=1.6.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.6.3)
# Requirement already satisfied, skipping upgrade: tika in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.24)
# Requirement already satisfied, skipping upgrade: httptools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.1.1)
# Requirement already satisfied, skipping upgrade: nltk in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (3.5)
# Requirement already satisfied, skipping upgrade: more_itertools in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (8.4.0)
# Requirement already satisfied, skipping upgrade: networkx in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.4)
# Requirement already satisfied, skipping upgrade: pymilvus in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.1.1)
# Requirement already satisfied, skipping upgrade: SPARQLWrapper in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.8.5)
# Requirement already satisfied, skipping upgrade: mmh3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (3.0.0)
# Requirement already satisfied, skipping upgrade: weaviate-client==2.5.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.5.0)
# Requirement already satisfied, skipping upgrade: ray==1.5.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.5.0)
# Requirement already satisfied, skipping upgrade: dataclasses-json in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.5.6)
# Requirement already satisfied, skipping upgrade: quantulum3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.7.9)
# Requirement already satisfied, skipping upgrade: psycopg2-binary in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.8.6)
# Requirement already satisfied, skipping upgrade: uvloop==0.14 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.14.0)
# Requirement already satisfied, skipping upgrade: future in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from torch<1.10,>1.5->farm-haystack==1.0.0rc1) (0.18.2)
# Requirement already satisfied, skipping upgrade: numpy in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from torch<1.10,>1.5->farm-haystack==1.0.0rc1) (1.18.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack==1.0.0rc1) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack==1.0.0rc1) (1.25.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack==1.0.0rc1) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from requests->farm-haystack==1.0.0rc1) (2.10)
# Requirement already satisfied, skipping upgrade: scikit-learn in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sklearn->farm-haystack==1.0.0rc1) (0.23.1)
# Requirement already satisfied, skipping upgrade: Keras>=2.2.4 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from seqeval->farm-haystack==1.0.0rc1) (2.4.3)
# Requirement already satisfied, skipping upgrade: simplejson in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.17.2)
# Requirement already satisfied, skipping upgrade: sqlparse in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.4.1)
# Requirement already satisfied, skipping upgrade: querystring-parser in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.2.4)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (5.3.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.13.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.15.0)
# Requirement already satisfied, skipping upgrade: cloudpickle in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.5.0)
# Requirement already satisfied, skipping upgrade: python-dateutil in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.8.1)
# Requirement already satisfied, skipping upgrade: alembic in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.4.3)
# Requirement already satisfied, skipping upgrade: gitpython>=2.1.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.1.11)
# Requirement already satisfied, skipping upgrade: entrypoints in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.3)
# Requirement already satisfied, skipping upgrade: docker>=3.6.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (4.3.1)
# Requirement already satisfied, skipping upgrade: Flask in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.2)
# Requirement already satisfied, skipping upgrade: databricks-cli>=0.8.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.14.0)
# Requirement already satisfied, skipping upgrade: click>=7.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (7.1.2)
# Requirement already satisfied, skipping upgrade: packaging in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (20.4)
# Requirement already satisfied, skipping upgrade: huggingface-hub==0.0.8 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (0.0.8)
# Requirement already satisfied, skipping upgrade: tokenizers<0.11,>=0.10.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (0.10.3)
# Requirement already satisfied, skipping upgrade: filelock in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (3.0.12)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (2020.6.8)
# Requirement already satisfied, skipping upgrade: sacremoses in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (0.0.43)
# Requirement already satisfied, skipping upgrade: starlette==0.13.6 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from fastapi->farm-haystack==1.0.0rc1) (0.13.6)
# Requirement already satisfied, skipping upgrade: pydantic<2.0.0,>=1.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from fastapi->farm-haystack==1.0.0rc1) (1.7.2)
# Requirement already satisfied, skipping upgrade: h11>=0.8 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from uvicorn->farm-haystack==1.0.0rc1) (0.11.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pandas->farm-haystack==1.0.0rc1) (2020.1)
# Requirement already satisfied, skipping upgrade: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (20.1.0)
# Requirement already satisfied, skipping upgrade: toml>=0.9.4 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (0.10.1)
# Requirement already satisfied, skipping upgrade: pluggy>=0.12.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (0.13.1)
# Requirement already satisfied, skipping upgrade: py>=1.4.17 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (1.9.0)
# Requirement already satisfied, skipping upgrade: sentencepiece in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.1.94)
# Requirement already satisfied, skipping upgrade: torchvision in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.11.1)
# Requirement already satisfied, skipping upgrade: lxml>=2.3.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from python-docx->farm-haystack==1.0.0rc1) (4.5.2)
# Requirement already satisfied, skipping upgrade: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from sqlalchemy>=1.4.2->farm-haystack==1.0.0rc1) (0.4.16)
# Requirement already satisfied, skipping upgrade: joblib in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from nltk->farm-haystack==1.0.0rc1) (0.16.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from networkx->farm-haystack==1.0.0rc1) (4.4.2)
# Requirement already satisfied, skipping upgrade: grpcio-tools<1.38.0,>=1.22.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pymilvus->farm-haystack==1.0.0rc1) (1.34.1)
# Requirement already satisfied, skipping upgrade: grpcio<1.38.0,>=1.22.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pymilvus->farm-haystack==1.0.0rc1) (1.35.0)
# Requirement already satisfied, skipping upgrade: ujson>=2.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from pymilvus->farm-haystack==1.0.0rc1) (4.0.2)
# Requirement already satisfied, skipping upgrade: rdflib>=4.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from SPARQLWrapper->farm-haystack==1.0.0rc1) (6.0.2)
# Requirement already satisfied, skipping upgrade: validators>=0.18.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from weaviate-client==2.5.0->farm-haystack==1.0.0rc1) (0.18.2)
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.0.0)
# Requirement already satisfied, skipping upgrade: opencensus in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.8.0)
# Requirement already satisfied, skipping upgrade: aiohttp in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.7.4.post0)
# Requirement already satisfied, skipping upgrade: jsonschema in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.2.0)
# Requirement already satisfied, skipping upgrade: aiohttp-cors in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.7.0)
# Requirement already satisfied, skipping upgrade: prometheus-client>=0.7.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.8.0)
# Requirement already satisfied, skipping upgrade: colorama in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.4.3)
# Requirement already satisfied, skipping upgrade: aioredis in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (2.0.0)
# Requirement already satisfied, skipping upgrade: py-spy>=0.2.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.3.10)
# Requirement already satisfied, skipping upgrade: redis>=3.5.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.5.3)
# Requirement already satisfied, skipping upgrade: gpustat in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.6.0)
# Requirement already satisfied, skipping upgrade: typing-inspect>=0.4.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from dataclasses-json->farm-haystack==1.0.0rc1) (0.7.1)
# Requirement already satisfied, skipping upgrade: marshmallow-enum<2.0.0,>=1.5.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from dataclasses-json->farm-haystack==1.0.0rc1) (1.5.1)
# Requirement already satisfied, skipping upgrade: marshmallow<4.0.0,>=3.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from dataclasses-json->farm-haystack==1.0.0rc1) (3.14.0)
# Requirement already satisfied, skipping upgrade: inflect in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from quantulum3->farm-haystack==1.0.0rc1) (5.3.0)
# Requirement already satisfied, skipping upgrade: num2words in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from quantulum3->farm-haystack==1.0.0rc1) (0.5.10)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn->farm-haystack==1.0.0rc1) (2.1.0)
# Requirement already satisfied, skipping upgrade: h5py in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Keras>=2.2.4->seqeval->farm-haystack==1.0.0rc1) (2.10.0)
# Requirement already satisfied, skipping upgrade: python-editor>=0.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from alembic->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.0.4)
# Requirement already satisfied, skipping upgrade: Mako in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from alembic->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.3)
# Requirement already satisfied, skipping upgrade: gitdb<5,>=4.0.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (4.0.5)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from docker>=3.6.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.57.0)
# Requirement already satisfied, skipping upgrade: Werkzeug>=0.15 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.16.1)
# Requirement already satisfied, skipping upgrade: Jinja2>=2.10.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.11.2)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.0)
# Requirement already satisfied, skipping upgrade: tabulate>=0.7.7 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from databricks-cli>=0.8.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.8.7)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from packaging->transformers==4.7.0->farm-haystack==1.0.0rc1) (2.4.7)
# Requirement already satisfied, skipping upgrade: distlib<1,>=0.3.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==1.0.0rc1) (0.3.1)
# Requirement already satisfied, skipping upgrade: appdirs<2,>=1.4.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==1.0.0rc1) (1.4.4)
# Requirement already satisfied, skipping upgrade: isodate in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper->farm-haystack==1.0.0rc1) (0.6.0)
# Requirement already satisfied, skipping upgrade: google-api-core<3.0.0,>=1.0.0; python_version >= "3.6" in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (2.1.1)
# Requirement already satisfied, skipping upgrade: opencensus-context==0.1.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.1.2)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (5.2.0)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (3.0.1)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (1.7.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (19.3.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (3.7.4.2)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from jsonschema->ray==1.5.0->farm-haystack==1.0.0rc1) (0.16.0)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gpustat->ray==1.5.0->farm-haystack==1.0.0rc1) (7.352.0)
# Requirement already satisfied, skipping upgrade: blessings>=1.6 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gpustat->ray==1.5.0->farm-haystack==1.0.0rc1) (1.7)
# Requirement already satisfied, skipping upgrade: mypy-extensions>=0.3.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->farm-haystack==1.0.0rc1) (0.4.3)
# Requirement already satisfied, skipping upgrade: docopt>=0.6.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from num2words->quantulum3->farm-haystack==1.0.0rc1) (0.6.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.9.2 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from Mako->alembic->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.1)
# Requirement already satisfied, skipping upgrade: smmap<4,>=3.0.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.0.4)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.53.0)
# Requirement already satisfied, skipping upgrade: google-auth<3.0dev,>=1.25.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (2.3.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.7.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.2.4)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.2.8)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /home/branden/Code/anaconda3/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.4.8)
# Building wheels for collected packages: farm-haystack
# done
#   Created wheel for farm-haystack: filename=farm_haystack-1.0.0rc1-py3-none-any.whl size=355705 sha256=1ef2b6a2c83642f14263608c968f1325050d8ed05f1ebab648931fb33d4eed24
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3rdilgvz/wheels/97/0d/ae/77cde17929fbf66c8320f19b30789acfe52e2312bb1d125be1
# Successfully built farm-haystack
# Installing collected packages: farm-haystack
#   Attempting uninstall: farm-haystack
#     Found existing installation: farm-haystack 1.0.0rc1
#     Uninstalling farm-haystack-1.0.0rc1:
#       Successfully uninstalled farm-haystack-1.0.0rc1
# Successfully installed farm-haystack-1.0.0rc1
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# Collecting pygraphviz
#   Downloading pygraphviz-1.7.zip (118 kB)
#      |████████████████████████████████| 118 kB 2.6 MB/s eta 0:00:01
# Building wheels for collected packages: pygraphviz
# error
#   ERROR: Command errored out with exit status 1:
#    command: /home/branden/Code/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-rweft665/pygraphviz/setup.py'"'"'; __file__='"'"'/tmp/pip-install-rweft665/pygraphviz/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-eiplfnq8
#        cwd: /tmp/pip-install-rweft665/pygraphviz/
#   Complete output (53 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/pygraphviz
#   copying pygraphviz/scraper.py -> build/lib.linux-x86_64-3.8/pygraphviz
#   copying pygraphviz/testing.py -> build/lib.linux-x86_64-3.8/pygraphviz
#   copying pygraphviz/graphviz.py -> build/lib.linux-x86_64-3.8/pygraphviz
#   copying pygraphviz/__init__.py -> build/lib.linux-x86_64-3.8/pygraphviz
#   copying pygraphviz/agraph.py -> build/lib.linux-x86_64-3.8/pygraphviz
#   creating build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_scraper.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/__init__.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_unicode.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_readwrite.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_attribute_defaults.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_edge_attributes.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_node_attributes.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_html.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_graph.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_string.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_drawing.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_close.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_layout.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_subgraph.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   copying pygraphviz/tests/test_clear.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#   running egg_info
#   writing pygraphviz.egg-info/PKG-INFO
#   writing dependency_links to pygraphviz.egg-info/dependency_links.txt
#   writing top-level names to pygraphviz.egg-info/top_level.txt
#   reading manifest file 'pygraphviz.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.png' under directory 'doc'
#   warning: no files found matching '*.txt' under directory 'doc'
#   warning: no files found matching '*.css' under directory 'doc'
#   warning: no previously-included files matching '*~' found anywhere in distribution
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   warning: no previously-included files matching '.svn' found anywhere in distribution
#   no previously-included directories found matching 'doc/build'
#   writing manifest file 'pygraphviz.egg-info/SOURCES.txt'
#   copying pygraphviz/graphviz.i -> build/lib.linux-x86_64-3.8/pygraphviz
#   copying pygraphviz/graphviz_wrap.c -> build/lib.linux-x86_64-3.8/pygraphviz
#   running build_ext
#   building 'pygraphviz._graphviz' extension
#   creating build/temp.linux-x86_64-3.8
#   creating build/temp.linux-x86_64-3.8/pygraphviz
#   gcc -pthread -B /home/branden/Code/anaconda3/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/home/branden/Code/anaconda3/include/python3.8 -c pygraphviz/graphviz_wrap.c -o build/temp.linux-x86_64-3.8/pygraphviz/graphviz_wrap.o
#   pygraphviz/graphviz_wrap.c:2711:10: fatal error: graphviz/cgraph.h: No such file or directory
#    2711 | #include "graphviz/cgraph.h"
#         |          ^~~~~~~~~~~~~~~~~~~
#   compilation terminated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pygraphviz
#   Running setup.py clean for pygraphviz
# Failed to build pygraphviz
# Installing collected packages: pygraphviz
# error
#     ERROR: Command errored out with exit status 1:
#      command: /home/branden/Code/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-rweft665/pygraphviz/setup.py'"'"'; __file__='"'"'/tmp/pip-install-rweft665/pygraphviz/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ghcz86xy/install-record.txt --single-version-externally-managed --compile --install-headers /home/branden/Code/anaconda3/include/python3.8/pygraphviz
#          cwd: /tmp/pip-install-rweft665/pygraphviz/
#     Complete output (53 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/pygraphviz
#     copying pygraphviz/scraper.py -> build/lib.linux-x86_64-3.8/pygraphviz
#     copying pygraphviz/testing.py -> build/lib.linux-x86_64-3.8/pygraphviz
#     copying pygraphviz/graphviz.py -> build/lib.linux-x86_64-3.8/pygraphviz
#     copying pygraphviz/__init__.py -> build/lib.linux-x86_64-3.8/pygraphviz
#     copying pygraphviz/agraph.py -> build/lib.linux-x86_64-3.8/pygraphviz
#     creating build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_scraper.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/__init__.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_unicode.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_readwrite.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_attribute_defaults.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_edge_attributes.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_node_attributes.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_html.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_graph.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_string.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_drawing.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_close.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_layout.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_subgraph.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     copying pygraphviz/tests/test_clear.py -> build/lib.linux-x86_64-3.8/pygraphviz/tests
#     running egg_info
#     writing pygraphviz.egg-info/PKG-INFO
#     writing dependency_links to pygraphviz.egg-info/dependency_links.txt
#     writing top-level names to pygraphviz.egg-info/top_level.txt
#     reading manifest file 'pygraphviz.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.png' under directory 'doc'
#     warning: no files found matching '*.txt' under directory 'doc'
#     warning: no files found matching '*.css' under directory 'doc'
#     warning: no previously-included files matching '*~' found anywhere in distribution
#     warning: no previously-included files matching '*.pyc' found anywhere in distribution
#     warning: no previously-included files matching '.svn' found anywhere in distribution
#     no previously-included directories found matching 'doc/build'
#     writing manifest file 'pygraphviz.egg-info/SOURCES.txt'
#     copying pygraphviz/graphviz.i -> build/lib.linux-x86_64-3.8/pygraphviz
#     copying pygraphviz/graphviz_wrap.c -> build/lib.linux-x86_64-3.8/pygraphviz
#     running build_ext
#     building 'pygraphviz._graphviz' extension
#     creating build/temp.linux-x86_64-3.8
#     creating build/temp.linux-x86_64-3.8/pygraphviz
#     gcc -pthread -B /home/branden/Code/anaconda3/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/home/branden/Code/anaconda3/include/python3.8 -c pygraphviz/graphviz_wrap.c -o build/temp.linux-x86_64-3.8/pygraphviz/graphviz_wrap.o
#     pygraphviz/graphviz_wrap.c:2711:10: fatal error: graphviz/cgraph.h: No such file or directory
#      2711 | #include "graphviz/cgraph.h"
#           |          ^~~~~~~~~~~~~~~~~~~
#     compilation terminated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /home/branden/Code/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-rweft665/pygraphviz/setup.py'"'"'; __file__='"'"'/tmp/pip-install-rweft665/pygraphviz/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ghcz86xy/install-record.txt --single-version-externally-managed --compile --install-headers /home/branden/Code/anaconda3/include/python3.8/pygraphviz Check the logs for full command output.

# %% [markdown]
# If running from Colab or a no Docker environment, you will want to start Elasticsearch from source

# %%
# In Colab / No Docker environments: Start Elasticsearch from source
! wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.2-linux-x86_64.tar.gz -q
! tar -xzf elasticsearch-7.9.2-linux-x86_64.tar.gz
! chown -R daemon:daemon elasticsearch-7.9.2

import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.9.2/bin/elasticsearch'],
                   stdout=PIPE, stderr=STDOUT,
                   preexec_fn=lambda: os.setuid(1)  # as daemon
                  )
# wait until ES has started
! sleep 30
# Out:
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-deprecation/x-pack-deprecation-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-deprecation/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-deprecation/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-deprecation/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-deprecation/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-deprecation': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/spatial/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/spatial/spatial-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/spatial/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/spatial/geo-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/spatial/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/spatial': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/aggs-matrix-stats/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/aggs-matrix-stats/aggs-matrix-stats-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/aggs-matrix-stats': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/repository-url/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/repository-url/repository-url-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/repository-url/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/repository-url': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/httpclient-4.5.10.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/kibana-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/httpasyncclient-4.1.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/commons-logging-1.1.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/httpcore-4.4.12.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/elasticsearch-ssl-config-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/httpcore-nio-4.4.12.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/elasticsearch-rest-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/reindex-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana/commons-codec-1.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/kibana': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/frozen-indices/frozen-indices-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/frozen-indices/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/frozen-indices/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/frozen-indices/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/frozen-indices': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-autoscaling/x-pack-autoscaling-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-autoscaling/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-autoscaling/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-autoscaling/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-autoscaling': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async/x-pack-async-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/percolator/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/percolator/percolator-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/percolator': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async-search/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async-search/x-pack-async-search-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async-search/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async-search/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async-search/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-async-search': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/constant-keyword/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/constant-keyword/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/constant-keyword/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/constant-keyword/constant-keyword-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/constant-keyword': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transform/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transform/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transform/transform-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transform/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transform': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/jcip-annotations-1.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-saml-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/guava-19.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-storage-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-xmlsec-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-soap-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-storage-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-messaging-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/slf4j-api-1.6.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-core-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-saml-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-profile-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-security-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/metrics-core-3.2.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/jakarta.mail-1.6.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/asm-7.3.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/lang-tag-1.4.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-xmlsec-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/httpclient-cache-4.5.10.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-security-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/oauth2-oidc-sdk-7.0.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-soap-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/json-smart-2.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/x-pack-security-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/xmlsec-2.1.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-profile-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/opensaml-messaging-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/java-support-7.5.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/log4j-slf4j-impl-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/accessors-smart-1.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/nimbus-jose-jwt-8.6.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security/cryptacular-1.2.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-security': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common/jcodings-1.0.44.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common/elasticsearch-dissect-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common/ingest-common-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common/elasticsearch-grok-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common/joni-2.1.29.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-common': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics/x-pack-analytics-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics/commons-math3-3.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-analytics': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/jakarta.mail-1.6.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/x-pack-watcher-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/jakarta.activation-1.2.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/guava-27.1-jre.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/owasp-java-html-sanitizer-20191001.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher/failureaccess-1.0.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-watcher': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/x-pack-sql-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/sql-action-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/sql-proto-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/aggs-matrix-stats-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-sql': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/vectors/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/vectors/vectors-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/vectors/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/vectors/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/vectors': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-codec-http-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/transport-netty4-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-handler-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-resolver-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-transport-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-buffer-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-common-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/netty-codec-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/transport-netty4': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/tasks/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/tasks/tasks-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/tasks': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-logstash/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-logstash/x-pack-logstash-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-logstash/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-logstash/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-logstash/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-logstash': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-graph/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-graph/x-pack-graph-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-graph/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-graph/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-graph/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-graph': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/lang-expression-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/asm-tree-5.0.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/antlr4-runtime-4.5.1-1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/asm-commons-5.0.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/asm-5.0.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/lucene-expressions-8.6.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-expression': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/mapper-extras/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/mapper-extras/mapper-extras-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/mapper-extras': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-saml-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/guava-19.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-storage-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-xmlsec-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-soap-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-storage-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-messaging-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/slf4j-api-1.6.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-core-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-saml-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-profile-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-security-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/metrics-core-3.2.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-xmlsec-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/x-pack-identity-provider-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/httpclient-cache-4.5.10.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-security-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-soap-api-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/xmlsec-2.1.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-profile-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/opensaml-messaging-impl-3.4.5.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/java-support-7.5.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/log4j-slf4j-impl-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider/cryptacular-1.2.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-identity-provider': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/analysis-common/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/analysis-common/analysis-common-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/analysis-common': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-data-streams/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-data-streams/x-pack-data-streams-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-data-streams/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-data-streams/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-data-streams': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-enrich/x-pack-enrich-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-enrich/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-enrich/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-enrich/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-enrich': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/x-pack-monitoring-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/elasticsearch-rest-client-sniffer-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/elasticsearch-rest-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-monitoring': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/GeoLite2-Country.mmdb': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/GeoLite2-City.mmdb': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/maxmind-db-1.3.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/ingest-geoip-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/geoip2-2.13.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/jackson-annotations-2.10.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/GeoLite2-ASN.mmdb': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/jackson-databind-2.10.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-geoip': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/httpclient-4.5.10.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/httpasyncclient-4.1.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/commons-logging-1.1.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/httpcore-4.4.12.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/elasticsearch-ssl-config-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/httpcore-nio-4.4.12.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/elasticsearch-rest-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/reindex-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex/commons-codec-1.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/reindex': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ilm/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ilm/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ilm/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ilm/x-pack-ilm-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ilm': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/flattened/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/flattened/flattened-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/flattened/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/flattened/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/flattened': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-stack/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-stack/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-stack/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-stack/x-pack-stack-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-stack': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-mustache/compiler-0.9.6.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-mustache/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-mustache/lang-mustache-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-mustache/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-mustache': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-user-agent/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-user-agent/ingest-user-agent-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/ingest-user-agent': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/parent-join/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/parent-join/parent-join-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/parent-join': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-rollup/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-rollup/x-pack-rollup-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-rollup/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-rollup/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-rollup/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-rollup': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ccr/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ccr/x-pack-ccr-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ccr/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ccr/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ccr/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ccr': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/asm-7.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/asm-analysis-7.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/asm-util-7.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/elasticsearch-scripting-painless-spi-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/lang-painless-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/asm-commons-7.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/antlr4-runtime-4.5.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/asm-tree-7.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/lang-painless': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/httpclient-4.5.10.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/elasticsearch-nio-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/httpasyncclient-4.1.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-codec-http-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/x-pack-core-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/commons-logging-1.1.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/transport-nio-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/transport-netty4-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-handler-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-resolver-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/httpcore-4.4.12.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-transport-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/elasticsearch-ssl-config-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/httpcore-nio-4.4.12.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/unboundid-ldapsdk-4.0.8.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-buffer-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-common-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/netty-codec-4.1.49.Final.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/log4j-1.2-api-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core/commons-codec-1.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-core': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/searchable-snapshots/searchable-snapshots-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/searchable-snapshots/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/searchable-snapshots/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/searchable-snapshots/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/searchable-snapshots': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/rank-eval/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/rank-eval/rank-eval-client-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/rank-eval': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ql/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ql/x-pack-ql-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ql/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ql/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ql': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-voting-only-node/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-voting-only-node/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-voting-only-node/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-voting-only-node/x-pack-voting-only-node-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-voting-only-node': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-eql/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-eql/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-eql/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-eql/x-pack-eql-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-eql/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-eql': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/jcodings-1.0.44.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/super-csv-2.4.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_date_time-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libMlMaths.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_filesystem-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libstdc++.so.6': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libMlCore.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_log-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_iostreams-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_thread-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_system-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libMlApi.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libMlModel.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_program_options-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_log_setup-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_regex-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_atomic-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libboost_chrono-gcc7-mt-x64-1_71.so.1.71.0': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libxml2.so.2': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib/libgcc_s.so.1': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/lib': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/resources/ml-en.dict': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/resources': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/bin/categorize': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/bin/autodetect': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/bin/controller': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/bin/normalize': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/bin/data_frame_analyzer': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64/bin': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform/linux-x86_64': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/platform': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/x-pack-ml-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/elasticsearch-grok-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/plugin-security-test.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/joni-2.1.29.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/icu4j-62.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/x-pack-ml': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/wildcard/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/wildcard/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/wildcard/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/wildcard/wildcard-7.9.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/modules/wildcard': Operation not permitted
# ...
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jcmd/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jcmd': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.prefs/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.prefs/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.prefs/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.prefs': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/jcup.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/bcel.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/xerces.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/xalan.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml/dom.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jdi/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jdi/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jdi/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jdi': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.management.jfr/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.management.jfr/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.management.jfr/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.management.jfr': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml.crypto/santuario.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml.crypto/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml.crypto/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml.crypto/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.xml.crypto': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.auth/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.auth/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.auth/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.auth': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.smartcardio/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.smartcardio/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.smartcardio/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.smartcardio/pcsclite.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.smartcardio': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.cryptoki/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.cryptoki/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.cryptoki/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.cryptoki/pkcs11wrapper.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.cryptoki/pkcs11cryptotoken.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.cryptoki': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.ec/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.ec/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.ec/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.ec/ecc.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.crypto.ec': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.ed/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.ed/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.ed/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.ed': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.localedata/thaidict.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.localedata/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.localedata/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.localedata/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.localedata/cldr.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.localedata': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.net/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.net/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.net/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.net': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jconsole/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jconsole/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jconsole/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jconsole': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.sctp/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.sctp/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.sctp/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.sctp': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.instrument/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.instrument/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.instrument/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.instrument': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.naming.dns/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.naming.dns/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.naming.dns/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.naming.dns': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql.rowset/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql.rowset/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql.rowset/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql.rowset': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.incubator.foreign/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.incubator.foreign/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.incubator.foreign/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.incubator.foreign': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.sql': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.jvmstat/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.jvmstat/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.jvmstat/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.jvmstat': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.unsupported.desktop/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.unsupported.desktop/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.unsupported.desktop/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.unsupported.desktop': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.hotspot.agent/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.hotspot.agent/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.hotspot.agent/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.hotspot.agent': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.httpserver/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.httpserver/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.httpserver/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.httpserver': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.opt/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.opt/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.opt/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.opt/jopt-simple.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.internal.opt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.jgss/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.jgss/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.jgss/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.security.jgss': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.transaction.xa/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.transaction.xa/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.transaction.xa/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/java.transaction.xa': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jstatd/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jstatd/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jstatd/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal/jdk.jstatd': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk/legal': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/jdk': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/logs': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2/README.asciidoc': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.9.2': Operation not permitted
# ---------------------------------------------------------------------------
# SubprocessError                           Traceback (most recent call last)
# <ipython-input-3-a924afee0725> in <module>
#       8 es_server = Popen(['elasticsearch-7.9.2/bin/elasticsearch'],
#       9                    stdout=PIPE, stderr=STDOUT,
# ---> 10                    preexec_fn=lambda: os.setuid(1)  # as daemon
#      11                   )
#      12 # wait until ES has started
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     798                                 c2pread, c2pwrite,
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#     802             # Cleanup if the child failed starting.
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
#    1551                     raise child_exception_type(errno_num, err_msg, err_filename)
# -> 1552                 raise child_exception_type(err_msg)
#    1553
#    1554
#
# SubprocessError: Exception occurred in preexec_fn.

# %% [markdown]
# ## Initialization

# %% [markdown]
# Then let's fetch some data (in this case, pages from the Game of Thrones wiki) and prepare it so that it can
# be used indexed into our `DocumentStore`

# %%
from haystack.utils import print_answers, print_documents, fetch_archive_from_http, convert_files_to_dicts, clean_wiki_text

#Download and prepare data - 517 Wikipedia articles for Game of Thrones
doc_dir = "data/article_txt_got"
s3_url = "https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/wiki_gameofthrones_txt.zip"
fetch_archive_from_http(url=s3_url, output_dir=doc_dir)

# convert files to dicts containing documents that can be indexed to our datastore
got_dicts = convert_files_to_dicts(
    dir_path=doc_dir,
    clean_func=clean_wiki_text,
    split_paragraphs=True
)
# Out:
# /home/branden/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)
# Found data stored in `data/article_txt_got`. Delete this first if you really want to fetch new data.
# Converting data/article_txt_got/145_Elio_M._García_Jr._and_Linda_Antonsson.txt
# Converting data/article_txt_got/401_Power_Is_Power.txt
# Converting data/article_txt_got/368_Jaime_Lannister.txt
# Converting data/article_txt_got/349_List_of_Game_of_Thrones_characters.txt
# Converting data/article_txt_got/39_Renly_Baratheon.txt
# Converting data/article_txt_got/330_Oberyn_Martell.txt
# Converting data/article_txt_got/79_Thronecast.txt
# Converting data/article_txt_got/447_You_Win_or_You_Die.txt
# Converting data/article_txt_got/332_Sansa_Stark.txt
# Converting data/article_txt_got/511_After_the_Thrones.txt
# Converting data/article_txt_got/461_The_Winds_of_Winter__Game_of_Thrones_.txt
# Converting data/article_txt_got/444_Cripples__Bastards__and_Broken_Things.txt
# Converting data/article_txt_got/360_List_of_Game_of_Thrones_episodes.txt
# Converting data/article_txt_got/378_A_Game_of_Thrones__board_game_.txt
# Converting data/article_txt_got/513_Oathbreaker__Game_of_Thrones_.txt
# Converting data/article_txt_got/133_Game_of_Thrones__Season_5__soundtrack_.txt
# Converting data/article_txt_got/217_The_Rogue_Prince.txt
# Converting data/article_txt_got/52_Catch_the_Throne.txt
# Converting data/article_txt_got/343_Catelyn_Stark.txt
# Converting data/article_txt_got/27_Game_of_Thrones__Season_4__soundtrack_.txt
# Converting data/article_txt_got/74_The_Prince_of_Winterfell.txt
# Converting data/article_txt_got/367_Gregor_Clegane.txt
# Converting data/article_txt_got/146_The_Sons_of_the_Dragon.txt
# Converting data/article_txt_got/80_A_Song_of_Ice_and_Fire_fandom.txt
# Converting data/article_txt_got/131_Mhysa.txt
# Converting data/article_txt_got/43_Arya_Stark.txt
# Converting data/article_txt_got/480_Varys.txt
# Converting data/article_txt_got/485_Oathkeeper.txt
# Converting data/article_txt_got/410_The_Bells__Game_of_Thrones_.txt
# Converting data/article_txt_got/310_Mother_s_Mercy.txt
# Converting data/article_txt_got/37_Joffrey_Baratheon.txt
# Converting data/article_txt_got/504_List_of_A_Song_of_Ice_and_Fire_video_games.txt
# Converting data/article_txt_got/232_Tommen_Baratheon.txt
# Converting data/article_txt_got/136_Game_of_Thrones__Season_8__soundtrack_.txt
# Converting data/article_txt_got/121_The_Bear_and_the_Maiden_Fair.txt
# Converting data/article_txt_got/7_The_Spoils_of_War__Game_of_Thrones_.txt
# Converting data/article_txt_got/469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt
# Converting data/article_txt_got/212_The_Children__Game_of_Thrones_.txt
# Converting data/article_txt_got/341_Ned_Stark.txt
# Converting data/article_txt_got/396_Game_of_Thrones__season_6_.txt
# Converting data/article_txt_got/346_Ygritte.txt
# Converting data/article_txt_got/424_Night_King.txt
# Converting data/article_txt_got/317_The_Broken_Man.txt
# Converting data/article_txt_got/262_Gilly__character_.txt
# Converting data/article_txt_got/0_Game_of_Thrones__season_8_.txt
# Converting data/article_txt_got/348_The_Winds_of_Winter.txt
# Converting data/article_txt_got/22_The_Rains_of_Castamere__song_.txt
# Converting data/article_txt_got/379_Davos_Seaworth.txt
# Converting data/article_txt_got/334_Rickon_Stark.txt
# Converting data/article_txt_got/482_Petyr_Baelish.txt
# Converting data/article_txt_got/454_Music_of_Game_of_Thrones.txt
# Converting data/article_txt_got/8_Eastwatch.txt
# Converting data/article_txt_got/508_A_Game_of_Thrones__Second_Edition__card_game_.txt
# Converting data/article_txt_got/446_A_Golden_Crown.txt
# Converting data/article_txt_got/1_Dragonstone__Game_of_Thrones_episode_.txt
# Converting data/article_txt_got/340_Roose_Bolton.txt
# Converting data/article_txt_got/453_Game_of_Thrones__2012_video_game_.txt
# Converting data/article_txt_got/402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt
# Converting data/article_txt_got/118_Dark_Wings__Dark_Words.txt
# Converting data/article_txt_got/311_Game_of_Thrones__season_7_.txt
# Converting data/article_txt_got/84_List_of_awards_and_nominations_received_by_Game_of_Thrones.txt
# Converting data/article_txt_got/154_Margaery_Tyrell.txt
# Converting data/article_txt_got/20_Light_of_the_Seven.txt
# Converting data/article_txt_got/495_Hodor.txt
# Converting data/article_txt_got/24_Game_of_Thrones__Season_1__soundtrack_.txt
# Converting data/article_txt_got/67_Unbowed__Unbent__Unbroken.txt
# Converting data/article_txt_got/120_And_Now_His_Watch_Is_Ended.txt
# Converting data/article_txt_got/198_A_Clash_of_Kings.txt
# Converting data/article_txt_got/44_Daenerys_Targaryen.txt
# Converting data/article_txt_got/199_A_Storm_of_Swords.txt
# Converting data/article_txt_got/306_The_Dance_of_Dragons.txt
# Converting data/article_txt_got/209_Mockingbird__Game_of_Thrones_.txt
# Converting data/article_txt_got/452_Fire_and_Blood__Game_of_Thrones_.txt
# Converting data/article_txt_got/129_Second_Sons.txt
# Converting data/article_txt_got/400_Winterfell__Game_of_Thrones_episode_.txt
# Converting data/article_txt_got/119_Walk_of_Punishment.txt
# Converting data/article_txt_got/407_The_Long_Night__Game_of_Thrones_.txt
# Converting data/article_txt_got/23_Game_of_Thrones_Live_Concert_Experience.txt
# Converting data/article_txt_got/25_Game_of_Thrones__Season_2__soundtrack_.txt
# Converting data/article_txt_got/514_Book_of_the_Stranger.txt
# Converting data/article_txt_got/9_Game_of_Thrones_Tapestry.txt
# Converting data/article_txt_got/475_A_Game_of_Thrones__role-playing_game_.txt
# Converting data/article_txt_got/53_The_Lion_and_the_Rose.txt
# Converting data/article_txt_got/477_A_Dance_with_Dragons.txt
# Converting data/article_txt_got/56_First_of_His_Name.txt
# Converting data/article_txt_got/439_Melisandre.txt
# Converting data/article_txt_got/85_Game_of_Thrones__Seven_Kingdoms.txt
# Converting data/article_txt_got/373_Tywin_Lannister.txt
# Converting data/article_txt_got/26_Game_of_Thrones__Season_3__soundtrack_.txt
# Converting data/article_txt_got/11_The_Dragon_and_the_Wolf.txt
# Converting data/article_txt_got/86_Game_of_Thrones__season_4_.txt
# Converting data/article_txt_got/75_Blackwater__Game_of_Thrones_.txt
# Converting data/article_txt_got/425_No_One__Game_of_Thrones_.txt
# Converting data/article_txt_got/501_Khal_Drogo.txt
# Converting data/article_txt_got/449_The_Pointy_End.txt
# Converting data/article_txt_got/51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt
# Converting data/article_txt_got/445_The_Wolf_and_the_Lion.txt
# Converting data/article_txt_got/347_Game_of_Thrones__season_2_.txt
# Converting data/article_txt_got/148_Game_of_Thrones__Winter_Is_Coming.txt
# Converting data/article_txt_got/73_A_Man_Without_Honor.txt
# Converting data/article_txt_got/443_The_Kingsroad.txt
# Converting data/article_txt_got/151_Ellaria_Sand.txt
# Converting data/article_txt_got/420_Blood_of_My_Blood.txt
# Converting data/article_txt_got/130_Game_of_Thrones_title_sequence.txt
# Converting data/article_txt_got/99_A_Song_of_Ass_and_Fire.txt
# Converting data/article_txt_got/365_A_Song_of_Ice_and_Fire_Roleplaying.txt
# Converting data/article_txt_got/68_The_Gift__Game_of_Thrones_.txt
# Converting data/article_txt_got/208_Robb_Stark.txt
# Converting data/article_txt_got/210_The_Mountain_and_the_Viper.txt
# Converting data/article_txt_got/40_Stannis_Baratheon.txt
# Converting data/article_txt_got/408_The_Last_of_the_Starks.txt
# Converting data/article_txt_got/345_A_Game_of_Thrones__comics_.txt
# Converting data/article_txt_got/460_Battle_of_the_Bastards.txt
# Converting data/article_txt_got/403_Jenny_of_Oldstones.txt
# Converting data/article_txt_got/160_Viserys_Targaryen.txt
# Converting data/article_txt_got/356_Tales_of_Dunk_and_Egg.txt
# Converting data/article_txt_got/213_Valyrian_languages.txt
# Converting data/article_txt_got/197_A_Game_of_Thrones.txt
# Converting data/article_txt_got/399_For_the_Throne__Music_Inspired_by_the_HBO_Series_Game_of_Thrones.txt
# Converting data/article_txt_got/481_Sandor_Clegane.txt
# Converting data/article_txt_got/304_Hardhome.txt
# Converting data/article_txt_got/329_Robert_Baratheon.txt
# Converting data/article_txt_got/395_Game_of_Thrones__season_5_.txt
# Converting data/article_txt_got/506_Game_of_Thrones_Theme.txt
# Converting data/article_txt_got/2_Stormborn.txt
# Converting data/article_txt_got/411_The_Iron_Throne__Game_of_Thrones_.txt
# Converting data/article_txt_got/362_Winter_Is_Coming.txt
# Converting data/article_txt_got/331_Bran_Stark.txt
# Converting data/article_txt_got/194_A_Song_of_Ice_and_Fire.txt
# Converting data/article_txt_got/474_Bronn__character_.txt
# Converting data/article_txt_got/54_Two_Swords__Game_of_Thrones_.txt
# Converting data/article_txt_got/3_The_Queen_s_Justice.txt
# Converting data/article_txt_got/512_Home__Game_of_Thrones_.txt
# Converting data/article_txt_got/77_Game_of_Thrones_Ascent.txt
# Converting data/article_txt_got/191_Gendry.txt
# Converting data/article_txt_got/98_Black_Friday__South_Park_.txt
# Converting data/article_txt_got/12_Fire.txt
# Converting data/article_txt_got/218_Olenna_Tyrell.txt
# Converting data/article_txt_got/10_Beyond_the_Wall__Game_of_Thrones_.txt
# Converting data/article_txt_got/127_The_Climb__Game_of_Thrones_.txt
# Converting data/article_txt_got/342_Theon_Greyjoy.txt
# Converting data/article_txt_got/369_Samwell_Tarly.txt
# Converting data/article_txt_got/211_The_Watchers_on_the_Wall.txt
# Converting data/article_txt_got/195_World_of_A_Song_of_Ice_and_Fire.txt
# Converting data/article_txt_got/102_The_Princess_and_the_Queen.txt
# Converting data/article_txt_got/233_Myrcella_Baratheon.txt
# Converting data/article_txt_got/359_Kill_the_Boy.txt
# Converting data/article_txt_got/30_List_of_A_Song_of_Ice_and_Fire_characters.txt
# Converting data/article_txt_got/33_David_Benioff.txt
# Converting data/article_txt_got/201_A_Game_of_Thrones__card_game_.txt
# Converting data/article_txt_got/134_Game_of_Thrones__Season_6__soundtrack_.txt
# Converting data/article_txt_got/487_Ramsay_Bolton.txt
# Converting data/article_txt_got/76_Valar_Morghulis.txt
# Converting data/article_txt_got/126_Kissed_by_Fire.txt
# Converting data/article_txt_got/97_Tyrion_Lannister.txt
# Converting data/article_txt_got/450_Baelor.txt
# Converting data/article_txt_got/371_Cersei_Lannister.txt
# Converting data/article_txt_got/78_The_Rains_of_Castamere.txt
# Converting data/article_txt_got/55_Breaker_of_Chains.txt
# Converting data/article_txt_got/224_The_Night_Lands.txt
# Converting data/article_txt_got/442_Game_of_Thrones__season_1_.txt
# Converting data/article_txt_got/515_The_Door__Game_of_Thrones_.txt
# Converting data/article_txt_got/263_Tormund_Giantsbane.txt
# Converting data/article_txt_got/214_Dothraki_language.txt
# Converting data/article_txt_got/135_Game_of_Thrones__Season_7__soundtrack_.txt
# Converting data/article_txt_got/435_White_Walker.txt
# Converting data/article_txt_got/456_Works_based_on_A_Song_of_Ice_and_Fire.txt
# Converting data/article_txt_got/488_Brienne_of_Tarth.txt
# Converting data/article_txt_got/229_Game_of_Thrones.txt
# Converting data/article_txt_got/87_Valar_Dohaeris.txt
# Converting data/article_txt_got/207_Jon_Snow__character_.txt
# Converting data/article_txt_got/202_A_Feast_for_Crows.txt
# Converting data/article_txt_got/299_Rani_Mahal__TV_series_.txt
# Converting data/article_txt_got/57_The_Laws_of_Gods_and_Men.txt
# Converting data/article_txt_got/228_Souad_Faress.txt
# Converting data/article_txt_got/273_High_Sparrow.txt
# Converting data/article_txt_got/101_Titties_and_Dragons.txt
# Converting data/article_txt_got/358_A_Game_of_Thrones__Genesis.txt
# Converting data/article_txt_got/193_Lord_Snow.txt
# Converting data/article_txt_got/21_The_Bear_and_the_Maiden_Fair__song_.txt
# Converting data/article_txt_got/69_The_Red_Woman.txt
# Converting data/article_txt_got/28_Jorah_Mormont.txt
# Converting data/article_txt_got/394_Game_of_Thrones__2014_video_game_.txt

# %% [markdown]
# Here we initialize the core components that we will be gluing together using the `Pipeline` class.
# We have a `DocumentStore`, an `ElasticsearchRetriever` and a `FARMReader`.
# These can be combined to create a classic Retriever-Reader pipeline that is designed
# to perform Open Domain Question Answering.

# %%
from haystack import Pipeline
from haystack.utils import launch_es
from haystack.document_stores import ElasticsearchDocumentStore
from haystack.nodes import ElasticsearchRetriever, DensePassageRetriever, FARMReader


# Initialize DocumentStore and index documents
launch_es()
document_store = ElasticsearchDocumentStore()
document_store.delete_documents()
document_store.write_documents(got_dicts)

# Initialize Sparse retriever
es_retriever = ElasticsearchRetriever(document_store=document_store)

# Initialize dense retriever
dpr_retriever = DensePassageRetriever(document_store)
document_store.update_embeddings(dpr_retriever, update_existing_embeddings=False)

reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2")
# Out:
# Starting Elasticsearch ...
# Tried to start Elasticsearch through Docker but this failed. It is likely that there is already an existing Elasticsearch instance running.
# Using devices: CUDA:0
# Number of GPUs: 1
# Updating embeddings for 2357 docs without embeddings ...
# Updating embeddings:   0%|          | 0/2357 [00:00<?, ? Docs/s]
# Create embeddings:   0%|          | 0/2368 [00:00<?, ? Docs/s]
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# <ipython-input-9-0895081b998a> in <module>
#      16 # Initialize dense retriever
#      17 dpr_retriever = DensePassageRetriever(document_store)
# ---> 18 document_store.update_embeddings(dpr_retriever, update_existing_embeddings=False)
#      19
#      20 reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2")
#
# ~/Code/haystack/haystack/document_stores/elasticsearch.py in update_embeddings(self, retriever, index, filters, update_existing_embeddings, batch_size)
#     988                     doc_updates.append(update)
#     989
# --> 990                 bulk(self.client, doc_updates, request_timeout=300, refresh=self.refresh_type)
#     991                 progress_bar.update(batch_size)
#     992
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/helpers/actions.py in bulk(client, actions, stats_only, *args, **kwargs)
#     325     # make streaming_bulk yield successful results so we can count them
#     326     kwargs["yield_ok"] = True
# --> 327     for ok, item in streaming_bulk(client, actions, *args, **kwargs):
#     328         # go through request-response pairs and detect failures
#     329         if not ok:
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/helpers/actions.py in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, *args, **kwargs)
#     255                         raise_on_error,
#     256                         *args,
# --> 257                         **kwargs
#     258                     ),
#     259                 ):
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/helpers/actions.py in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, *args, **kwargs)
#     141         # default behavior - just propagate exception
#     142         if raise_on_exception:
# --> 143             raise e
#     144
#     145         # if we are not propagating, mark all actions in current chunk as failed
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/helpers/actions.py in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, *args, **kwargs)
#     137     try:
#     138         # send the actual request
# --> 139         resp = client.bulk("\n".join(bulk_actions) + "\n", *args, **kwargs)
#     140     except TransportError as e:
#     141         # default behavior - just propagate exception
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     150                 if p in kwargs:
#     151                     params[p] = kwargs.pop(p)
# --> 152             return func(*args, params=params, headers=headers, **kwargs)
#     153
#     154         return _wrapped
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/client/__init__.py in bulk(self, body, index, doc_type, params, headers)
#     447             params=params,
#     448             headers=headers,
# --> 449             body=body,
#     450         )
#     451
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     390                         raise e
#     391                 else:
# --> 392                     raise e
#     393
#     394             else:
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     363                     headers=headers,
#     364                     ignore=ignore,
# --> 365                     timeout=timeout,
#     366                 )
#     367
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     267                 method, full_url, url, orig_body, duration, response.status, raw_data
#     268             )
# --> 269             self._raise_error(response.status, raw_data)
#     270
#     271         self.log_request_success(
#
# ~/Code/anaconda3/envs/haystack/lib/python3.7/site-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     299
#     300         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# --> 301             status_code, error_message, additional_info
#     302         )
#     303
#
# TransportError: TransportError(429, 'circuit_breaking_exception', '[parent] Data too large, data for [<http_request>] would be [132507078/126.3mb], which is larger than the limit of [127506841/121.5mb], real usage: [116988416/111.5mb], new bytes reserved: [15518662/14.7mb], usages [request=0/0b, fielddata=0/0b, in_flight_requests=15518662/14.7mb, model_inference=0/0b, accounting=20600/20.1kb]')

# %% [markdown]
# ## Prebuilt Pipelines
#
# Haystack features many prebuilt pipelines that cover common tasks.
# Here we have an `ExtractiveQAPipeline` (the successor to the now deprecated `Finder` class).

# %%
from haystack.pipelines import ExtractiveQAPipeline

# Prebuilt pipeline
p_extractive_premade = ExtractiveQAPipeline(reader=reader, retriever=es_retriever)
res = p_extractive_premade.run(
    query="Who is the father of Arya Stark?",
    params={"Retriever": {"top_k": 10}, "Reader": {"top_k": 5}},
)
print_answers(res, details="minimal")

# %% [markdown]
# If you want to just do the retrieval step, you can use a `DocumentSearchPipeline`

# %%
from haystack.pipelines import DocumentSearchPipeline

p_retrieval = DocumentSearchPipeline(es_retriever)
res = p_retrieval.run(
    query="Who is the father of Arya Stark?",
    params={"Retriever": {"top_k": 10}},
)
print_documents(res, max_text_len=200)

# %% [markdown]
# Or if you want to use a `Generator` instead of a `Reader`,
# you can initialize a `GenerativeQAPipeline` like this:

# %%
from haystack.pipelines import GenerativeQAPipeline, FAQPipeline
from haystack.nodes import RAGenerator

# We set this to True so that the document store returns document embeddings with each document
# This is needed by the Generator
document_store.return_embedding = True

# Initialize generator
rag_generator = RAGenerator()

# Generative QA
p_generator = GenerativeQAPipeline(generator=rag_generator, retriever=dpr_retriever)
res = p_generator.run(
    query="Who is the father of Arya Stark?",
    params={"Retriever": {"top_k": 10}}
)
print_answers(res, details="minimal")

# We are setting this to False so that in later pipelines,
# we get a cleaner printout
document_store.return_embedding = False

# %% [markdown]
# Haystack features prebuilt pipelines to do:
# - just document search (DocumentSearchPipeline),
# - document search with summarization (SearchSummarizationPipeline)
# - generative QA (GenerativeQAPipeline)
# - FAQ style QA (FAQPipeline)
# - translated search (TranslationWrapperPipeline)
# To find out more about these pipelines, have a look at our [documentation](https://haystack.deepset.ai/docs/latest/pipelinesmd)

# %% [markdown]
# With any Pipeline, whether prebuilt or custom constructed,
# you can save a diagram showing how all the components are connected.
#
# ![image](https://user-images.githubusercontent.com/1563902/102451716-54813700-4039-11eb-881e-f3c01b47ca15.png)

# %%
p_extractive_premade.draw("pipeline_extractive_premade.png")
p_retrieval.draw("pipeline_retrieval.png")
p_generator.draw("pipeline_generator.png")

# %% [markdown]
# ## Custom Pipelines
#
# Now we are going to rebuild the `ExtractiveQAPipelines` using the generic Pipeline class.
# We do this by adding the building blocks that we initialized as nodes in the graph.

# %%
# Custom built extractive QA pipeline
p_extractive = Pipeline()
p_extractive.add_node(component=es_retriever, name="Retriever", inputs=["Query"])
p_extractive.add_node(component=reader, name="Reader", inputs=["Retriever"])

# Now we can run it
res = p_extractive.run(
    query="Who is the father of Arya Stark?",
    params={"Retriever": {"top_k": 10}, "Reader": {"top_k": 5}}
)
print_answers(res, details="minimal")
p_extractive.draw("pipeline_extractive.png")

# %% [markdown]
# Pipelines offer a very simple way to ensemble together different components.
# In this example, we are going to combine the power of a `DensePassageRetriever`
# with the keyword based `ElasticsearchRetriever`.
# See our [documentation](https://haystack.deepset.ai/docs/latest/retrievermd) to understand why
# we might want to combine a dense and sparse retriever.
#
# ![image](https://user-images.githubusercontent.com/1563902/102451782-7bd80400-4039-11eb-9046-01b002a783f8.png)
#
# Here we use a `JoinDocuments` node so that the predictions from each retriever can be merged together.

# %%
from haystack.pipelines import JoinDocuments

# Create ensembled pipeline
p_ensemble = Pipeline()
p_ensemble.add_node(component=es_retriever, name="ESRetriever", inputs=["Query"])
p_ensemble.add_node(component=dpr_retriever, name="DPRRetriever", inputs=["Query"])
p_ensemble.add_node(component=JoinDocuments(join_mode="concatenate"), name="JoinResults", inputs=["ESRetriever", "DPRRetriever"])
p_ensemble.add_node(component=reader, name="Reader", inputs=["JoinResults"])
p_ensemble.draw("pipeline_ensemble.png")

# Run pipeline
res = p_ensemble.run(
    query="Who is the father of Arya Stark?",
    params={"DPRRetriever": {"top_k": 5}, "ESRetriever": {"top_k": 5}}
)
print_answers(res, details="minimal")

# %% [markdown]
# ## Custom Nodes
#
# Nodes are relatively simple objects
# and we encourage our users to design their own if they don't see on that fits their use case
#
# The only requirements are:
# - Create a class that inherits `BaseComponent`.
# - Add a method run() to your class. Add the mandatory and optional arguments it needs to process. These arguments must be passed as input to the pipeline, inside `params`, or output by preceding nodes.
# - Add processing logic inside the run() (e.g. reformatting the query).
# - Return a tuple that contains your output data (for the next node)
# and the name of the outgoing edge (by default "output_1" for nodes that have one output)
# - Add a class attribute outgoing_edges = 1 that defines the number of output options from your node. You only need a higher number here if you have a decision node (see below).
#
# Here we have a template for a Node:

# %%
from haystack import BaseComponent
from typing import Optional

class CustomNode(BaseComponent):
    outgoing_edges = 1

    def run(self, query: str, my_optional_param: Optional[int]):
        # process the inputs
        output = {"my_output": ...}
        return output, "output_1"

# %% [markdown]
# ## Decision Nodes
#
# Decision Nodes help you route your data so that only certain branches of your `Pipeline` are run.
# One popular use case for such query classifiers is routing keyword queries to Elasticsearch and questions to DPR + Reader.
# With this approach you keep optimal speed and simplicity for keywords while going deep with transformers when it's most helpful.
#
# ![image](https://user-images.githubusercontent.com/1563902/102452199-41229b80-403a-11eb-9365-7038697e7c3e.png)
#
# Though this looks very similar to the ensembled pipeline shown above,
# the key difference is that only one of the retrievers is run for each request.
# By contrast both retrievers are always run in the ensembled approach.
#
# Below, we define a very naive `QueryClassifier` and show how to use it:

# %%
class CustomQueryClassifier(BaseComponent):
    outgoing_edges = 2

    def run(self, query: str):
        if "?" in query:
            return {}, "output_2"
        else:
            return {}, "output_1"

# Here we build the pipeline
p_classifier = Pipeline()
p_classifier.add_node(component=CustomQueryClassifier(), name="QueryClassifier", inputs=["Query"])
p_classifier.add_node(component=es_retriever, name="ESRetriever", inputs=["QueryClassifier.output_1"])
p_classifier.add_node(component=dpr_retriever, name="DPRRetriever", inputs=["QueryClassifier.output_2"])
p_classifier.add_node(component=reader, name="QAReader", inputs=["ESRetriever", "DPRRetriever"])
p_classifier.draw("pipeline_classifier.png")

# Run only the dense retriever on the full sentence query
res_1 = p_classifier.run(query="Who is the father of Arya Stark?")
print("DPR Results" + "\n" + "="*15)
print_answers(res_1)

# Run only the sparse retriever on a keyword based query
res_2 = p_classifier.run(query="Arya Stark father")
print("ES Results" + "\n" + "="*15)
print_answers(res_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5df2cbd0f79a> in <module>
#      13 p_classifier.add_node(component=es_retriever, name="ESRetriever", inputs=["QueryClassifier.output_1"])
#      14 p_classifier.add_node(component=dpr_retriever, name="DPRRetriever", inputs=["QueryClassifier.output_2"])
# ---> 15 p_classifier.add_node(component=reader, name="QAReader", inputs=["ESRetriever", "DPRRetriever"])
#      16 p_classifier.draw("pipeline_classifier.png")
#      17
#
# NameError: name 'reader' is not defined

# %% [markdown]
# ## Evaluation Nodes
#
# We have also designed a set of nodes that can be used to evaluate the performance of a system.
# Have a look at our [tutorial](https://haystack.deepset.ai/docs/latest/tutorial5md) to get hands on with the code and learn more about Evaluation Nodes!

# %% [markdown]
# ## Debugging Pipelines
#
# You can print out debug information from nodes in your pipelines in two different ways.

# %%
# 1) You can set the `debug` attribute of a given node.
es_retriever.debug = True

# 2) You can provide `debug` as a parameter when running your pipeline
result = p_classifier.run(
    query="Who is the father of Arya Stark?",
    params={
        "ESRetriever": {
            "debug": True
        }
    }
)

result["_debug"]

# %% [markdown]
# ## YAML Configs
#
# A full `Pipeline` can be defined in a YAML file and simply loaded.
# Having your pipeline available in a YAML is particularly useful
# when you move between experimentation and production environments.
# Just export the YAML from your notebook / IDE and import it into your production environment.
# It also helps with version control of pipelines,
# allows you to share your pipeline easily with colleagues,
# and simplifies the configuration of pipeline parameters in production.
#
# It consists of two main sections: you define all objects (e.g. a reader) in components
# and then stick them together to a pipeline in pipelines.
# You can also set one component to be multiple nodes of a pipeline or to be a node across multiple pipelines.
# It will be loaded just once in memory and therefore doesn't hurt your resources more than actually needed.
#
# The contents of a YAML file should look something like this:

# %% [markdown]
# ```yaml
# version: '0.7'
# components:    # define all the building-blocks for Pipeline
# - name: MyReader       # custom-name for the component; helpful for visualization & debugging
#   type: FARMReader    # Haystack Class name for the component
#   params:
#     no_ans_boost: -10
#     model_name_or_path: deepset/roberta-base-squad2
# - name: MyESRetriever
#   type: ElasticsearchRetriever
#   params:
#     document_store: MyDocumentStore    # params can reference other components defined in the YAML
#     custom_query: null
# - name: MyDocumentStore
#   type: ElasticsearchDocumentStore
#   params:
#     index: haystack_test
# pipelines:    # multiple Pipelines can be defined using the components from above
# - name: my_query_pipeline    # a simple extractive-qa Pipeline
#   nodes:
#   - name: MyESRetriever
#     inputs: [Query]
#   - name: MyReader
#     inputs: [MyESRetriever]
# ```

# %% [markdown]
# To load, simply call:
# ``` python
# pipeline.load_from_yaml(Path("sample.yaml"))
# ```

# %% [markdown]
# ## Conclusion
#
# The possibilities are endless with the `Pipeline` class and we hope that this tutorial will inspire you
# to build custom pipeplines that really work for your use case!

# %% [markdown]
# ## About us
#
# This [Haystack](https://github.com/deepset-ai/haystack/) notebook was made with love by [deepset](https://deepset.ai/) in Berlin, Germany
#
# We bring NLP to the industry via open source!
# Our focus: Industry specific language models & large scale QA systems.
#
# Some of our other work:
# - [German BERT](https://deepset.ai/german-bert)
# - [GermanQuAD and GermanDPR](https://deepset.ai/germanquad)
# - [FARM](https://github.com/deepset-ai/FARM)
#
# Get in touch:
# [Twitter](https://twitter.com/deepset_ai) | [LinkedIn](https://www.linkedin.com/company/deepset-ai/) | [Slack](https://haystack.deepset.ai/community/join) | [GitHub Discussions](https://github.com/deepset-ai/haystack/discussions) | [Website](https://deepset.ai)
#
# By the way: [we're hiring!](https://www.deepset.ai/jobs)
