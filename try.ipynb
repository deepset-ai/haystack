# %%
from haystack.dataclasses.chat_message import ImageContent, ChatMessage, TextContent, ChatRole

image = ImageContent.from_file_path("test/test_files/images/apple.jpg")

# %%
user_message = ChatMessage(
    _role=ChatRole.USER,
    _content=[TextContent("What are in this image?"), ImageContent.from_file_path("test/test_files/images/apple.jpg")],
)

# %%
user_message
# Out:
# ChatMessage(_role=<ChatRole.USER: 'user'>, _content=[TextContent(text='What are in this image?'), ImageContent(base64_image='...')], _name=None, _meta={})

# %%
user_message.to_openai_dict_format()
# Out:
# {'role': 'user', 'content': 'What are in this image?'}

# %%
from haystack.components.generators.chat import OpenAIChatGenerator

generator = OpenAIChatGenerator()

print(generator.run([user_message]))
# Out:
# {'replies': [ChatMessage(_role=<ChatRole.ASSISTANT: 'assistant'>, _content=[TextContent(text="I'm sorry, but I cannot view images. However, if you describe the image to me, I can help you analyze or understand it better!")], _name=None, _meta={'model': 'gpt-4o-mini-2024-07-18', 'index': 0, 'finish_reason': 'stop', 'usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), 'prompt_tokens_details': PromptTokensDetails(audio_tokens=0, cached_tokens=0)}})]}

# %%
from openai import OpenAI

client = OpenAI()
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "What are in this image?"}
                # {
                #     "type": "image_url",
                #     "image_url": {
                #         "url": f"data:image/jpeg;base64,{image.base64_image}",
                #     },
                # },
            ],
        }
    ],
    max_tokens=300,
)

# %%
print(response.choices[0])
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="I'm sorry, but I can't see images or interpret visual content. However, if you describe the image to me, I'll be happy to help with any information or questions you have about it!", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))
